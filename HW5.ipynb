# %%
import file_loader as fl
import data_preprocessing as dp
from extra_trees_regressor import run_extra_trees
from lgbm_regressor import run_lgbm
from random_forest_regressor import run_random_forest
from huber_regressor import run_huber
from lasso_regressor import run_lasso
from model_comparison import compare_models
#Загрузка датасета
file_path = 'ObesityDataSet.csv'
df = fl.load_data(file_path)

data_preprocessing = dp.preprocess_data(df)

compare_models(data_preprocessing)
# Out:
# Данные успешно загружены. Размер: (2111, 17)
# ___ СРАВНЕНИЕ РЕГРЕССОРОВ ___
# ___ Extra Trees Regressor ___
# ___ Результаты Extra Trees Regressor ___
# Среднеквадратичная ошибка (MSE): 10.2268
# Средняя абсолютная ошибка (MAE): 2.0212
# Корень из среднеквадратичной ошибки (RMSE): 3.1979
# Коэффициент детерминации (R²): 0.9855
# ___ LightGBM Regressor ___
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.070978 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1821
# [LightGBM] [Info] Number of data points in the train set: 1688, number of used features: 16
# [LightGBM] [Info] Start training from score 86.598197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ___ Результаты LightGBM Regressor ___
# Среднеквадратичная ошибка (MSE): 9.7397
# Средняя абсолютная ошибка (MAE): 2.0839
# Корень из среднеквадратичной ошибки (RMSE): 3.1208
# Коэффициент детерминации (R²): 0.9862
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ___ Random Forest Regressor ___
# ___ Результаты Random Forest Regressor ___
# Среднеквадратичная ошибка (MSE): 8.2618
# Средняя абсолютная ошибка (MAE): 1.6918
# Корень из среднеквадратичной ошибки (RMSE): 2.8743
# Коэффициент детерминации (R²): 0.9883
# ____ Huber Regressor ___
# ___ Результаты Huber Regressor ___
# Среднеквадратичная ошибка (MSE): 294.5517
# Средняя абсолютная ошибка (MAE): 13.6448
# Корень из среднеквадратичной ошибки (RMSE): 17.1625
# Коэффициент детерминации (R²): 0.5823
# ___ Lasso Regressor ___
# ___ Результаты Lasso Regressor ___
# Среднеквадратичная ошибка (MSE): 286.4267
# Средняя абсолютная ошибка (MAE): 13.8999
# Корень из среднеквадратичной ошибки (RMSE): 16.9241
# Коэффициент детерминации (R²): 0.5938
# ___ ИТОГОВОЕ СРАВНЕНИЕ МОДЕЛЕЙ ___
#                     MSE      MAE     RMSE      R2
# Extra Trees     10.2268   2.0212   3.1979  0.9855
# LightGBM         9.7397   2.0839   3.1208  0.9862
# Random Forest    8.2618   1.6918   2.8743  0.9883
# Huber          294.5517  13.6448  17.1625  0.5823
# Lasso          286.4267  13.8999  16.9241  0.5938
# ___ ЛУЧШИЕ МОДЕЛИ ___
# Лучшая модель по R²: Random Forest (R² = 0.9883)
# Лучшая модель по MSE: Random Forest (MSE = 8.2618)
#                       MSE        MAE       RMSE        R2
# Extra Trees     10.226816   2.021214   3.197939  0.985496
# LightGBM         9.739657   2.083878   3.120842  0.986187
# Random Forest    8.261816   1.691770   2.874337  0.988283
# Huber          294.551684  13.644795  17.162508  0.582262
# Lasso          286.426691  13.899917  16.924145  0.593785
